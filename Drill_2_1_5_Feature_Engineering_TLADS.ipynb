# %% [markdown]
# # TLADS Drill
# Categorize each of the variables in the ESS dataset as categorical or continuous, and if continuous as ordinal, interval, or ratio variables. Check your work with your mentor, and discuss what that information might imply for feature engineering with this data.

# %%
import pandas as pd

# load the ESS dataset
df = pd.read_csv("https://raw.githubusercontent.com/Thinkful-Ed/data-201-resources/master/ESS_practice_data/ESSdata_Thinkful.csv")

# %%
df.head(10)
# Out:
#   cntry  idno  year  tvtot  ppltrst  pplfair  pplhlp  happy  sclmeet  sclact  \
# 0    CH   5.0     6    3.0      3.0     10.0     5.0    8.0      5.0     4.0
# 1    CH  25.0     6    6.0      5.0      7.0     5.0    9.0      3.0     2.0
# 2    CH  26.0     6    1.0      8.0      8.0     8.0    7.0      6.0     3.0
# 3    CH  28.0     6    4.0      6.0      6.0     7.0   10.0      6.0     2.0
# 4    CH  29.0     6    5.0      6.0      7.0     5.0    8.0      7.0     2.0
# 5    CH  36.0     6    4.0      6.0      7.0     3.0    8.0      7.0     4.0
# 6    CH  40.0     6    3.0      0.0      5.0     2.0    0.0      2.0     2.0
# 7    CH  41.0     6    2.0      4.0      5.0     3.0   10.0      5.0     2.0
# 8    CH  51.0     6    2.0      8.0      8.0     8.0    9.0      6.0     4.0
# 9    CH  53.0     6    4.0      4.0      4.0     8.0    7.0      4.0     2.0
#
#    gndr  agea  partner
# 0   2.0  60.0      1.0
# 1   2.0  59.0      1.0
# 2   1.0  24.0      2.0
# 3   2.0  64.0      1.0
# ...

# %% [markdown]
# When I answer the type of varialbes, I referred to the [codebook](https://thinkful-ed.github.io/data-201-resources/ESS_practice_data/ESS_codebook.html) of ESS.
#
# 1. **```cntry```**: categorical
# 1. **```idno```**: categorical
# 1. **```year```**: categorical
# 1. **```tvtot```**: continuous, ratio
# 1. **```ppltrst```**: continuous, ordinal
# 1. **```pplfair```**: continuous, ordinal
# 1. **```pplhlp```**: continuous, ordinal
# 1. **```happy```**: continuous, ordinal
# 1. **```sclmeet```**: continuous, ordinal
# 1. **```sclact```**: continuous, ordinal
# 1. **```gndr```**: categorical
# 1. **```agea```**: continuous, ratio
# 1. **```partner```**: categorical
